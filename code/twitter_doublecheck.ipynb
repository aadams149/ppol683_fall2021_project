# %%
import os, sys
import numpy as np
import twint
import pandas as pd
from datetime import datetime, timedelta, date
import nest_asyncio
nest_asyncio.apply()

# %%
os.chdir('C:/Users/alexi/Desktop/PPOL683/final_project/')

# %%
handles = pd.read_csv('data/counties.csv')

# %%
handles_only.head(10)
# Out:
#    fips               name state state_full         twitter  twitterYN  \
# 0  1003     Baldwin County    AL    Alabama      baldwinema          1
# 1  1013      Butler County    AL    Alabama    butlerco_ema          1
# 2  1015     Calhoun County    AL    Alabama  BeReadyCalhoun          1
# 3  1023     Choctaw County    AL    Alabama      ChoctawEMA          1
# 4  1049      DeKalb County    AL    Alabama   DeKalb_Co_EMA          1
# 5  1073   Jefferson County    AL    Alabama      jcdhtweets          1
# 6  1083   Limestone County    AL    Alabama    LimestoneEMA          1
# 7  1095    Marshall County    AL    Alabama         McemaAl          1
# 8  1097      Mobile County    AL    Alabama       ILoveMCHD          1
# 9  1101  Montgomery County    AL    Alabama      MCCAlabama          1
#
#                   twitterNotes  facebook facebookNotes          notes district
# 0  Emergency Management Agency       1.0        Active    EmergManage      NaN
# 1  Emergency Management Agency       1.0        Active    EmergManage      NaN
# 2                          NaN       1.0        Active    EmergManage      NaN
# 3                          NaN       1.0        Active    EmergManage      NaN
# 4                          NaN       1.0        Active    EmergManage      NaN
# 5                          NaN       1.0        Active            NaN      NaN
# 6                          NaN       1.0        Active    EmergManage      NaN
# 7                          NaN       1.0        Active    EmergManage      NaN
# 8                          NaN       1.0        Active            NaN      NaN
# 9                          NaN       1.0        Active  CountyGeneral      NaN

# %%
handles_only = handles.dropna(subset = ['twitter']).reset_index(drop = True)

# %%
for i in range(0, len(handles_only)):
    
    suffix = '.csv'
    dir_name = 'C:/Users/alexi/Desktop/PPOL683/final_project/data/most_recent_tweets'
    file_name = handles_only.loc[i, 'name']+'_'+handles_only.loc[i,'state_full']

    config = twint.Config()
    config.Username = handles_only.loc[i, 'twitter']
    config.Limit = 1
    config.Output = os.path.join(dir_name, file_name+suffix)
    config.Hide_output = True
    #config.Custom["tweet"] = ["id", "conversation_id", "date", "time", "user_id", 
    #                          "username", "name", "tweet", "language", "retweet", 
    #                          "retweets_count", "replies_count", "likes_count", 
    #                          "hashtags", "link", "video"]
    config.Store_csv = True

    try:
        print(handles_only.loc[i, 'name'], " ", i+1, "of", len(handles_only))
        twint.run.Search(config)
    
    except ValueError:
        continue
# Out:
# DeKalb County   225 of 775
# Douglas County   226 of 775
# DuPage County   227 of 775
# Ford County   228 of 775
# Greene County   229 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Grundy County   230 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Hardin County   231 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jackson County   232 of 775
# Johnson County   233 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Kane County   234 of 775
# Kankakee County   235 of 775
# Kendall County   236 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Knox County   237 of 775
# Lake County   238 of 775
# LaSalle County   239 of 775
# Lee County   240 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# McHenry County   241 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# McLean County   242 of 775
# Macon County   243 of 775
# Macoupin County   244 of 775
# Madison County   245 of 775
# Marion County   246 of 775
# Massac County   247 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Ogle County   248 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Peoria County   249 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Perry County   250 of 775
# Pope County   251 of 775
# Pulaski County   252 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Rock Island County   253 of 775
# St. Clair County   254 of 775
# Union County   255 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Whiteside County   256 of 775
# Will County   257 of 775
# Winnebago County   258 of 775
# Woodford County   259 of 775
# Allen County   260 of 775
# Clark County   261 of 775
# Floyd County   262 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Hendricks County   263 of 775
# Henry County   264 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Marion County   265 of 775
# Monroe County   266 of 775
# Montgomery County   267 of 775
# Morgan County   268 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Parke County   269 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Porter County   270 of 775
# St. Joseph County   271 of 775
# Tippecanoe County   272 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Tipton County   273 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Vanderburgh County   274 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Vigo County   275 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Wayne County   276 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Black Hawk County   277 of 775
# Buena Vista County   278 of 775
# Carroll County   279 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Cass County   280 of 775
# Cerro Gordo County   281 of 775
# Crawford County   282 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Dallas County   283 of 775
# Grundy County   284 of 775
# Harrison County   285 of 775
# Jasper County   286 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Johnson County   287 of 775
# Jones County   288 of 775
# Linn County   289 of 775
# Madison County   290 of 775
# Mitchell County   291 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Osceola County   292 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Palo Alto County   293 of 775
# Polk County   294 of 775
# Pottawattamie County   295 of 775
# Scott County   296 of 775
# Taylor County   297 of 775
# Warren County   298 of 775
# Webster County   299 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Woodbury County   300 of 775
# Cowley County   301 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Crawford County   302 of 775
# Douglas County   303 of 775
# Edwards County   304 of 775
# Ellis County   305 of 775
# Geary County   306 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Lyon County   307 of 775
# Morris County   308 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Osage County   309 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Ottawa County   310 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Pawnee County   311 of 775
# Riley County   312 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Saline County   313 of 775
# Shawnee County   314 of 775
# Wyandotte County   315 of 775
# CRITICAL:root:twint.get:User:'user'
# Adair County   316 of 775
# Barren County   317 of 775
# Bath County   318 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Boone County   319 of 775
# Boyd County   320 of 775
# Bullitt County   321 of 775
# Butler County   322 of 775
# Campbell County   323 of 775
# Carroll County   324 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Casey County   325 of 775
# Christian County   326 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Clark County   327 of 775
# Clinton County   328 of 775
# Cumberland County   329 of 775
# Daviess County   330 of 775
# Edmonson County   331 of 775
# Fayette County   332 of 775
# Gallatin County   333 of 775
# Grant County   334 of 775
# Graves County   335 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Green County   336 of 775
# Greenup County   337 of 775
# Hancock County   338 of 775
# Hardin County   339 of 775
# CRITICAL:root:twint.get:User:'user'
# Harrison County   340 of 775
# Hart County   341 of 775
# Henderson County   342 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Henry County   343 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jefferson County   344 of 775
# Jessamine County   345 of 775
# Kenton County   346 of 775
# Knott County   347 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Larue County   348 of 775
# CRITICAL:root:twint.get:User:'user'
# Laurel County   349 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Lee County   350 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Leslie County   351 of 775
# Letcher County   352 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Logan County   353 of 775
# McCreary County   354 of 775
# McLean County   355 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Madison County   356 of 775
# Marion County   357 of 775
# CRITICAL:root:twint.get:User:'user'
# Mason County   358 of 775
# CRITICAL:root:twint.get:User:'user'
# Meade County   359 of 775
# CRITICAL:root:twint.get:User:'user'
# Menifee County   360 of 775
# Mercer County   361 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Metcalfe County   362 of 775
# Monroe County   363 of 775
# Morgan County   364 of 775
# Nelson County   365 of 775
# CRITICAL:root:twint.get:User:'user'
# Nicholas County   366 of 775
# Ohio County   367 of 775
# Owen County   368 of 775
# Owsley County   369 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Pendleton County   370 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Perry County   371 of 775
# Pike County   372 of 775
# Pulaski County   373 of 775
# Robertson County   374 of 775
# CRITICAL:root:twint.get:User:'user'
# Rowan County   375 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Russell County   376 of 775
# Scott County   377 of 775
# Shelby County   378 of 775
# Simpson County   379 of 775
# Spencer County   380 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Taylor County   381 of 775
# Trimble County   382 of 775
# Union County   383 of 775
# Warren County   384 of 775
# Washington County   385 of 775
# CRITICAL:root:twint.get:User:'user'
# Wayne County   386 of 775
# Webster County   387 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Whitley County   388 of 775
# Wolfe County   389 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Woodford County   390 of 775
# Knox County   391 of 775
# Waldo County   392 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Allegany County   393 of 775
# Anne Arundel County   394 of 775
# Calvert County   395 of 775
# Carroll County   396 of 775
# Cecil County   397 of 775
# Charles County   398 of 775
# Frederick County   399 of 775
# Garrett County   400 of 775
# Harford County   401 of 775
# Howard County   402 of 775
# Montgomery County   403 of 775
# Prince George's County   404 of 775
# St. Mary's County   405 of 775
# Washington County   406 of 775
# Wicomico County   407 of 775
# Worcester County   408 of 775
# Baltimore city   409 of 775
# Barnstable County   410 of 775
# Nantucket County   411 of 775
# Plymouth County   412 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Worcester County   413 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Alger County   414 of 775
# Allegan County   415 of 775
# Antrim County   416 of 775
# Arenac County   417 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Baraga County   418 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Barry County   419 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Charlevoix County   420 of 775
# Clare County   421 of 775
# Clinton County   422 of 775
# Crawford County   423 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Eaton County   424 of 775
# Emmet County   425 of 775
# Genesee County   426 of 775
# Gladwin County   427 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Gogebic County   428 of 775
# Grand Traverse County   429 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Gratiot County   430 of 775
# Houghton County   431 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Ingham County   432 of 775
# Isabella County   433 of 775
# Kalamazoo County   434 of 775
# Kalkaska County   435 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Kent County   436 of 775
# Keweenaw County   437 of 775
# Lake County   438 of 775
# Luce County   439 of 775
# Mackinac County   440 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Macomb County   441 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Manistee County   442 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Mason County   443 of 775
# Mecosta County   444 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Missaukee County   445 of 775
# Montcalm County   446 of 775
# Newaygo County   447 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Oakland County   448 of 775
# Oceana County   449 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Ontonagon County   450 of 775
# Osceola County   451 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Otsego County   452 of 775
# Ottawa County   453 of 775
# Roscommon County   454 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Saginaw County   455 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# St. Clair County   456 of 775
# Schoolcraft County   457 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Shiawassee County   458 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Tuscola County   459 of 775
# Washtenaw County   460 of 775
# Wexford County   461 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Carver County   462 of 775
# Clay County   463 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# McLeod County   464 of 775
# Sherburne County   465 of 775
# Adair County   466 of 775
# Audrain County   467 of 775
# Butler County   468 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Caldwell County   469 of 775
# Cape Girardeau County   470 of 775
# Clay County   471 of 775
# Cole County   472 of 775
# Dade County   473 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Dallas County   474 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jackson County   475 of 775
# Jefferson County   476 of 775
# Lincoln County   477 of 775
# Macon County   478 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Phelps County   479 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Pike County   480 of 775
# Platte County   481 of 775
# Randolph County   482 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# St. Charles County   483 of 775
# St. Louis County   484 of 775
# Taney County   485 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Warren County   486 of 775
# Cascade County   487 of 775
# Gallatin County   488 of 775
# Jefferson County   489 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Adams County   490 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Antelope County   491 of 775
# Arthur County   492 of 775
# Blaine County   493 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Boyd County   494 of 775
# Brown County   495 of 775
# Buffalo County   496 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Burt County   497 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Butler County   498 of 775
# Cass County   499 of 775
# Cedar County   500 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Chase County   501 of 775
# Cherry County   502 of 775
# Clay County   503 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Cuming County   504 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Custer County   505 of 775
# Dawson County   506 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Dixon County   507 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Dodge County   508 of 775
# Douglas County   509 of 775
# Dundy County   510 of 775
# Fillmore County   511 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Franklin County   512 of 775
# Frontier County   513 of 775
# Furnas County   514 of 775
# Gage County   515 of 775
# Garfield County   516 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Gosper County   517 of 775
# Greeley County   518 of 775
# Harlan County   519 of 775
# Hayes County   520 of 775
# Hitchcock County   521 of 775
# Holt County   522 of 775
# Hooker County   523 of 775
# Howard County   524 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jefferson County   525 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Johnson County   526 of 775
# Kearney County   527 of 775
# Keith County   528 of 775
# Keya Paha County   529 of 775
# Knox County   530 of 775
# Lancaster County   531 of 775
# Lincoln County   532 of 775
# Logan County   533 of 775
# Loup County   534 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# McPherson County   535 of 775
# Madison County   536 of 775
# Nemaha County   537 of 775
# Nuckolls County   538 of 775
# Otoe County   539 of 775
# Pawnee County   540 of 775
# Perkins County   541 of 775
# Phelps County   542 of 775
# Pierce County   543 of 775
# Polk County   544 of 775
# Red Willow County   545 of 775
# Richardson County   546 of 775
# Saline County   547 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Sarpy County   548 of 775
# Saunders County   549 of 775
# Seward County   550 of 775
# Sherman County   551 of 775
# Stanton County   552 of 775
# Thayer County   553 of 775
# Thomas County   554 of 775
# Thurston County   555 of 775
# Valley County   556 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Washington County   557 of 775
# Wayne County   558 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Webster County   559 of 775
# Wheeler County   560 of 775
# York County   561 of 775
# Washoe County   562 of 775
# Strafford County   563 of 775
# Hunterdon County   564 of 775
# Monmouth County   565 of 775
# Ocean County   566 of 775
# Salem County   567 of 775
# Somerset County   568 of 775
# Warren County   569 of 775
# Chautauqua County   570 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Chemung County   571 of 775
# Clinton County   572 of 775
# Cortland County   573 of 775
# Erie County   574 of 775
# Greene County   575 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Kings County   576 of 775
# Lewis County   577 of 775
# Monroe County   578 of 775
# Ontario County   579 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Orleans County   580 of 775
# Oswego County   581 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Rockland County   582 of 775
# Saratoga County   583 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Schuyler County   584 of 775
# Steuben County   585 of 775
# Suffolk County   586 of 775
# Tioga County   587 of 775
# Tompkins County   588 of 775
# Ulster County   589 of 775
# Warren County   590 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Washington County   591 of 775
# Westchester County   592 of 775
# Wyoming County   593 of 775
# Yates County   594 of 775
# Alamance County   595 of 775
# Avery County   596 of 775
# Bertie County   597 of 775
# Burke County   598 of 775
# Cabarrus County   599 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Caldwell County   600 of 775
# Camden County   601 of 775
# Cherokee County   602 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Chowan County   603 of 775
# Currituck County   604 of 775
# Forsyth County   605 of 775
# Gates County   606 of 775
# Halifax County   607 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Harnett County   608 of 775
# Hertford County   609 of 775
# Hoke County   610 of 775
# McDowell County   611 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Macon County   612 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# New Hanover County   613 of 775
# Onslow County   614 of 775
# Orange County   615 of 775
# Pasquotank County   616 of 775
# Perquimans County   617 of 775
# Rockingham County   618 of 775
# Stokes County   619 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Wilson County   620 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Yancey County   621 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Burleigh County   622 of 775
# LaMoure County   623 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Allen County   624 of 775
# Ashland County   625 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Ashtabula County   626 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Athens County   627 of 775
# Auglaize County   628 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Brown County   629 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Butler County   630 of 775
# Carroll County   631 of 775
# Clark County   632 of 775
# Clermont County   633 of 775
# Cuyahoga County   634 of 775
# Darke County   635 of 775
# Defiance County   636 of 775
# Delaware County   637 of 775
# Fayette County   638 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Franklin County   639 of 775
# Gallia County   640 of 775
# Greene County   641 of 775
# Guernsey County   642 of 775
# Hamilton County   643 of 775
# Hancock County   644 of 775
# Henry County   645 of 775
# Hocking County   646 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Holmes County   647 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jefferson County   648 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Lake County   649 of 775
# Logan County   650 of 775
# Lucas County   651 of 775
# Madison County   652 of 775
# Mahoning County   653 of 775
# Medina County   654 of 775
# Meigs County   655 of 775
# Mercer County   656 of 775
# Miami County   657 of 775
# Montgomery County   658 of 775
# Morrow County   659 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Muskingum County   660 of 775
# Noble County   661 of 775
# Perry County   662 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Pickaway County   663 of 775
# Pike County   664 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Preble County   665 of 775
# Putnam County   666 of 775
# Richland County   667 of 775
# Ross County   668 of 775
# Sandusky County   669 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Scioto County   670 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Stark County   671 of 775
# Tuscarawas County   672 of 775
# Union County   673 of 775
# Warren County   674 of 775
# Wayne County   675 of 775
# Wood County   676 of 775
# Wyandot County   677 of 775
# Beckham County   678 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Caddo County   679 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Cleveland County   680 of 775
# Comanche County   681 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Cotton County   682 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Greer County   683 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Harmon County   684 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Jackson County   685 of 775
# Kiowa County   686 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Oklahoma County   687 of 775
# Tillman County   688 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Tulsa County   689 of 775
# Washita County   690 of 775
# Josephine County   691 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Lane County   692 of 775
# Lincoln County   693 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Malheur County   694 of 775
# Marion County   695 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Morrow County   696 of 775
# Multnomah County   697 of 775
# Umatilla County   698 of 775
# Allegheny County   699 of 775
# Chester County   700 of 775
# Erie County   701 of 775
# Montgomery County   702 of 775
# Providence County   703 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Hamilton County   704 of 775
# Madison County   705 of 775
# Shelby County   706 of 775
# Sullivan County   707 of 775
# Sumner County   708 of 775
# Angelina County   709 of 775
# Austin County   710 of 775
# Bexar County   711 of 775
# Brazos County   712 of 775
# Cameron County   713 of 775
# Chambers County   714 of 775
# Dallas County   715 of 775
# Denton County   716 of 775
# CRITICAL:root:twint.get:User:'user'
# Fort Bend County   717 of 775
# Galveston County   718 of 775
# Grayson County   719 of 775
# Harris County   720 of 775
# Hidalgo County   721 of 775
# McLennan County   722 of 775
# Nueces County   723 of 775
# Tarrant County   724 of 775
# Taylor County   725 of 775
# Travis County   726 of 775
# Victoria County   727 of 775
# Wichita County   728 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Williamson County   729 of 775
# Daggett County   730 of 775
# Davis County   731 of 775
# Duchesne County   732 of 775
# Salt Lake County   733 of 775
# Summit County   734 of 775
# Uintah County   735 of 775
# Utah County   736 of 775
# Wasatch County   737 of 775
# Arlington County   738 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Augusta County   739 of 775
# Fairfax County   740 of 775
# Loudoun County   741 of 775
# Alexandria city   742 of 775
# Adams County   743 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Clallam County   744 of 775
# Clark County   745 of 775
# Ferry County   746 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Grant County   747 of 775
# King County   748 of 775
# Kitsap County   749 of 775
# Klickitat County   750 of 775
# Lewis County   751 of 775
# Mason County   752 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Pierce County   753 of 775
# San Juan County   754 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Thurston County   755 of 775
# Walla Walla County   756 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Whitman County   757 of 775
# Yakima County   758 of 775
# CRITICAL:root:twint.get:User:'user'
# Kanawha County   759 of 775
# Lincoln County   760 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Marion County   761 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Brown County   762 of 775
# Clark County   763 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Door County   764 of 775
# Fond du Lac County   765 of 775
# Jefferson County   766 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Milwaukee County   767 of 775
# Oneida County   768 of 775
# Outagamie County   769 of 775
# Ozaukee County   770 of 775
# Sauk County   771 of 775
# Sheboygan County   772 of 775
# Winnebago County   773 of 775
# Campbell County   774 of 775
# Sweetwater County   775 of 775
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
import glob

# %%
path = 'C:/Users/alexi/Desktop/PPOL683/final_project/data/most_recent_tweets' # use your path
globbed_files = glob.glob(path + "/*.csv")

# %%
data = []
for csv in globbed_files:
    frame = pd.read_csv(csv)
    frame['filename'] = os.path.basename(csv)
    data.append(frame)

# %%
data = pd.concat(data, ignore_index = True)

# %%
data.shape
# Out:
# (9276, 37)

# %%
data.to_csv('data/most_recent_tweets.csv', index = False)
